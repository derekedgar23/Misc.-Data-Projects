# %% [markdown]
# <a href="https://colab.research.google.com/github/derekedgar23/Sports--Data-Projects-/blob/main/TTU_Week_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/derekedgar23/Texas_Tech_Football_2024_Public/refs/heads/main/TTU%20CINCI%20-%20Sheet1.csv')

# %%
df
# Out:
#        Offense Offense Conference        Defense Defense Conference  \
# 0   Cincinnati             Big 12         Towson                CAA
# 1   Cincinnati             Big 12         Towson                CAA
# 2   Cincinnati             Big 12         Towson                CAA
# 3   Cincinnati             Big 12         Towson                CAA
# 4   Cincinnati             Big 12         Towson                CAA
# ..         ...                ...            ...                ...
# 91  Texas Tech             Big 12  Arizona State             Big 12
# 92  Texas Tech             Big 12  Arizona State             Big 12
# 93  Texas Tech             Big 12  Arizona State             Big 12
# 94  Texas Tech             Big 12  Arizona State             Big 12
# 95  Texas Tech             Big 12  Arizona State             Big 12
#
#       Game Id           Id  Drive Number  Scoring  Start Period  \
# 0   401628591   4016285911             1     True             1
# ...

# %%
df.fillna(0.0, inplace=True) #replace blank with 0.0

# %%
X = df[['Start Yardline']]
y = df['Yards']

# %%
model = LinearRegression()
model.fit(X, y)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X)

# %%
plt.scatter(df['Start Yardline'], df['Yards'])
plt.xlabel('Start Yardline')
plt.ylabel('Yards')
plt.title('Scatter Plot of Start Yardline vs Yards')
plt.plot(X['Start Yardline'], y_pred, color='red', linewidth=2)
plt.show()

# %%
X_train = df[['Start Yardline']]

# %%
y_train = df['Yards']

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
X_train
# Out:
#     Start Yardline
# 0               25
# 1               35
# 2               25
# 3                3
# 4               37
# ..             ...
# 91              52
# 92              35
# 93              35
# 94              32
# 95              58
#
# [96 rows x 1 columns]

# %%
y_train
# Out:
# 0     75
# 1     65
# 2     75
# 3     39
# 4     63
#       ..
# 91     1
# 92    43
# 93    43
# 94    -8
# 95    -3
# Name: Yards, Length: 96, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X_train, y_train, test_size=0.4)

# %%
X_train
# Out:
#     Start Yardline
# 82              21
# 18              60
# 75              25
# 1               35
# 66              61
# 43              29
# 73              20
# 77              44
# 0               25
# 76              70
# 50              65
# 62              71
# 4               37
# 51              42
# 81              57
# 9               20
# 45              25
# 86              14
# 8               19
# 68              75
# 65              57
# 16              44
# 25              75
# 37              47
# 10              13
# 85              62
# 84              35
# 20              25
# 35              20
# 47              30
# 52              25
# 87              15
# 91              52
# 6               30
# 69              95
# 11              32
# 57              70
# 56              75
# 5               34
# 27              95
# 55              92
# 26               3
# 29               0
# 60              75
# 17              42
# 90              32
# ...

# %%
X_test
# Out:
#     Start Yardline
# 41              32
# 49              29
# 32              88
# 15              38
# 93              35
# 2               25
# 83              25
# 40              45
# 28               0
# 13              20
# 58              86
# 70              44
# 74              75
# 61              75
# 88              42
# 7               36
# 24              63
# 34              55
# 72              25
# 22              25
# 64              92
# 92              35
# 30              59
# 71              28
# 95              58
# 80              25
# 39              11
# 94              32
# 12              25
# 53              33
# 14              25
# 38               6
# 89              24
# 19              22
# 33              26
# 63              70
# 59              92
# 31              80
# 36              20

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_lr_train_pred = lr.predict(X_train)
y_lr_test_pred = lr.predict(X_test)

# %%
y_lr_train_pred
# Out:
# array([43.22917799, 33.95306438, 42.27778172, 39.89929105, 33.71521531,
#        41.32638545, 43.46702705, 37.75864945, 42.27778172, 31.57457371,
#        32.76381905, 31.33672465, 39.42359292, 38.23434758, 34.66661158,
#        43.46702705, 42.27778172, 44.89412146, 43.70487612, 30.38532838,
#        34.66661158, 37.75864945, 30.38532838, 37.04510225, 45.13197052,
#        33.47736625, 39.89929105, 42.27778172, 43.46702705, 41.08853639,
#        42.27778172, 44.65627239, 35.85585692, 41.08853639, 25.62834704,
#        40.61283825, 31.57457371, 30.38532838, 40.13714012, 25.62834704,
#        26.34189424, 47.51046119, 48.22400839, 30.38532838, 38.23434758,
#        40.61283825, 47.51046119, 28.48253584, 37.99649852, 35.14230972,
#        29.19608304, 45.84551772, 30.38532838, 42.27778172, 30.62317745,
#        42.27778172, 42.27778172])

# %%
y_lr_test_pred
# Out:
# array([40.61283825, 41.32638545, 27.29329051, 39.18574385, 39.89929105,
#        42.27778172, 42.27778172, 37.52080038, 48.22400839, 43.46702705,
#        27.76898864, 37.75864945, 30.38532838, 30.38532838, 38.23434758,
#        39.66144198, 33.23951718, 35.14230972, 42.27778172, 42.27778172,
#        26.34189424, 39.89929105, 34.19091345, 41.56423452, 34.42876251,
#        42.27778172, 45.60766866, 40.61283825, 42.27778172, 40.37498919,
#        42.27778172, 46.79691399, 42.51563079, 42.99132892, 42.03993265,
#        31.57457371, 26.34189424, 29.19608304, 43.46702705])

# %%
from sklearn.metrics import mean_squared_error, r2_score

lr_train_mse = mean_squared_error(y_train, y_lr_train_pred)
lr_train_r2 = r2_score(y_train, y_lr_train_pred)

lr_test_mse = mean_squared_error(y_test, y_lr_test_pred)
lr_test_r2 = r2_score(y_test, y_lr_test_pred)

# %%
lr_train_mse
# Out:
# 712.3790728674742

# %%
lr_train_r2
# Out:
# 0.04788013397999469

# %%
lr_test_mse
# Out:
# 780.6674175383515

# %%
lr_test_r2
# Out:
# 0.05230225721564352

# %%
print('LR MSE (Train): ', lr_train_mse)
print('LR R2 (Train): ', lr_train_r2)
print('LR MSE (Test): ', lr_test_mse)
print('LR R2 (Test): ', lr_test_r2)
# Out:
# LR MSE (Train):  712.3790728674742
# LR R2 (Train):  0.04788013397999469
# LR MSE (Test):  780.6674175383515
# LR R2 (Test):  0.05230225721564352

# %%
lr_results = pd.DataFrame(['Linear Regression', lr_train_mse, lr_train_r2, lr_test_mse, lr_test_r2]).transpose()
lr_results.columns = ['Method', 'Training MSE', 'Training R2', 'Test MSE', 'Test R2']

# %%
lr_results
# Out:
#               Method Training MSE Training R2    Test MSE   Test R2
# 0  Linear Regression   712.379073     0.04788  780.667418  0.052302

# %%
from sklearn.ensemble import RandomForestRegressor

rf=RandomForestRegressor(max_depth = 2, random_state = 0)
rf.fit(X_train, y_train)
# Out:
# RandomForestRegressor(max_depth=2, random_state=0)

# %%
y_rf_train_pred = rf.predict(X_train)
y_rf_test_pred = rf.predict(X_test)

# %%
rf_train_mse = mean_squared_error(y_train, y_rf_train_pred)
rf_train_r2 = r2_score(y_train, y_rf_train_pred)

rf_test_mse = mean_squared_error(y_test, y_rf_test_pred)
rf_test_r2 = r2_score(y_test, y_rf_test_pred)

# %%
rf_results = pd.DataFrame(['Random Forest', rf_train_mse, rf_train_r2, rf_test_mse, rf_test_r2]).transpose()
rf_results.columns = ['Method', 'Training MSE', 'Training R2', 'Test MSE', 'Test R2']

# %%
rf_results
# Out:
#           Method Training MSE Training R2    Test MSE   Test R2
# 0  Random Forest   389.251794    0.479751  892.832344 -0.083861

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(5, 5))
plt.scatter(x=y_train, y=y_lr_train_pred, c="#7CAE00",alpha=0.3)

z = np.polyfit(y_train, y_lr_train_pred, 1)
p = np.poly1d(z)

plt.plot(y_train, p(y_train), '#F8766D')
plt.ylabel('Predict Yards Gained ')
plt.xlabel("Yard Line")
plt.ylabel("Predicted Yards Gained")
# Out:
# Text(0, 0.5, 'Predicted Yards Gained')
